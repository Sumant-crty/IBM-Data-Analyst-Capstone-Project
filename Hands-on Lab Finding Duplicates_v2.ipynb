# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
duplicate_rows = df[df.duplicated()]
num_duplicates = duplicate_rows.shape[0]

print(f"Number of duplicate rows: {num_duplicates}")
print("\nFirst few duplicate rows:")
display(duplicate_rows.head())
# Out:
# Number of duplicate rows: 20
#
# First few duplicate rows:
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
# Task 2: Analysis of Duplicate Response Patterns
# Identify duplicate response patterns based on selected columns
subset_cols = ['MainBranch', 'Employment', 'RemoteWork']
# Using keep=False to mark all occurrences of a duplicate pattern as True
duplicate_patterns_subset = df[df.duplicated(subset=subset_cols, keep=False)]

print(f"Number of rows with duplicate patterns based on '{', '.join(subset_cols)}': {duplicate_patterns_subset.shape[0]}")
print("\nFirst few rows exhibiting these duplicate patterns:")
display(duplicate_patterns_subset.head())

print("\nClarification: These 'duplicate patterns' indicate multiple respondents who provided identical answers for the 'MainBranch', 'Employment', and 'RemoteWork' questions. This is distinct from a 'duplicate record' which implies an entire row being identical. It suggests a shared characteristic among different survey responses.\n")

print("Analysis of other columns frequently sharing identical values within these response-pattern groups:")
# Group by the subset columns and analyze other columns
grouped_patterns = duplicate_patterns_subset.groupby(subset_cols)

# Iterate through each group (unique combination of MainBranch, Employment, RemoteWork)
for name, group in grouped_patterns:
    print(f"\nPattern: MainBranch={name[0]}, Employment={name[1]}, RemoteWork={name[2]}")
    print(f"Number of respondents sharing this pattern: {len(group)}")
    # Analyze other columns within this group
    for col in df.columns.difference(subset_cols + ['ResponseId']): # Exclude ResponseId and the subset columns
        if len(group[col].unique()) == 1: # If all values in this column are the same within the group
            print(f"  Column '{col}' consistently has value: '{group[col].iloc[0]}'")
        elif group[col].nunique() > 1 and group[col].nunique() < 5: # If there are a few distinct values, show their counts
            print(f"  Column '{col}' values distribution:")
            print(group[col].value_counts().to_string())
# Out:
# Number of rows with duplicate patterns based on 'MainBranch, Employment, RemoteWork': 65290
#
# First few rows exhibiting these duplicate patterns:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
# Task 3: Visualize Shared Response Patterns

# 1. Distribution of shared patterns by Country
# Get value counts for 'Country' within the subset of duplicate patterns
country_pattern_counts = duplicate_patterns_subset['Country'].value_counts().head(10) # Top 10 countries

plt.figure(figsize=(12, 6))
country_pattern_counts.plot(kind='bar')
plt.title('Top 10 Countries with Shared MainBranch, Employment, RemoteWork Patterns')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 2. Distribution of shared patterns by Employment
# Get value counts for 'Employment' within the subset of duplicate patterns
employment_pattern_counts = duplicate_patterns_subset['Employment'].value_counts()

plt.figure(figsize=(10, 6))
employment_pattern_counts.plot(kind='bar')
plt.title('Distribution of Shared MainBranch, Employment, RemoteWork Patterns by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_311/2766298834.py:26: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# ###1. Analyse the dataset to determine which column(s) define record uniqueness.
#
# In this dataset, the ResponseId column uniquely identifies each survey response. Each ResponseId should correspond to a single, distinct survey submission from an individual. Therefore, ResponseId is the primary column defining record uniqueness.
#
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
#
# Removing rows based on a subset of columns, such as MainBranch, Employment, and RemoteWork, is generally not appropriate for this type of survey data if the goal is to analyze individual responses. Here's why:
#
# Nature of Survey Data: Survey data captures responses from many different individuals. It is highly probable and entirely legitimate for multiple distinct individuals to share identical demographic information or responses to general questions (e.g., two different developers both being 'Employed, full-time', 'Remote', and identifying as 'I am a developer by profession'). These are not duplicate records of the same individual but rather represent multiple unique respondents who happen to share those characteristics.
#
# Loss of Valuable Data: If we were to remove rows based on shared values in MainBranch, Employment, and RemoteWork, we would be discarding actual, unique survey responses. This would artificially reduce the sample size and skew any statistical analysis or insights derived from the data, as it would misrepresent the true distribution of these characteristics among respondents.
#
# Distinction from True Duplicates: The 20 full duplicate rows identified in Task 1 (where all columns were identical, implying the same ResponseId or at least a complete copy of an entry) are true duplicates that should be removed to maintain data integrity. These are likely errors in data collection or processing. However, the 'duplicate patterns' observed in Task 2 simply highlight shared characteristics among distinct respondents.
#
# Justification: The primary purpose of collecting survey data is to gather unique insights from a population. Each unique ResponseId represents a distinct individual's contribution. While shared patterns in demographic or professional columns are interesting for segmentation and understanding population characteristics, treating them as 'duplicates' for removal would undermine the integrity of the survey results by eliminating valid, distinct data points. Therefore, we should only remove rows that are entirely identical across all columns, as indicated by the ResponseId and other fields, not merely those sharing common attributes in a subset of columns.

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# #Identification of Duplicates:
#
# Full Row Duplicates: We first identified complete duplicate rows using df.duplicated(). This identified rows where every single column had an identical value. This yielded 20 truly duplicate records.
# Partial Duplicates/Shared Patterns: We then analyzed 'duplicate patterns' based on a subset of key demographic columns: MainBranch, Employment, and RemoteWork. Using df.duplicated(subset=subset_cols, keep=False), we identified respondents who shared identical answers for these specific questions. This revealed a large number of rows (65,290) exhibiting these shared patterns, indicating multiple individuals with similar profiles rather than exact duplicate entries.
# Removal of Duplicates:
#
# Strategy for Full Duplicates: The 20 full duplicate rows identified initially should be removed. This is because they represent redundant information, likely due to data entry errors or processing issues, and would skew any statistical analysis if left in. The removal can be done using df.drop_duplicates(inplace=True).
# Strategy for Partial Duplicates/Shared Patterns: We decided not to remove rows based on the shared patterns of MainBranch, Employment, and RemoteWork. These are not true duplicates of individuals but rather represent multiple unique respondents who happen to share the same characteristics in these specific categories. Removing them would lead to a loss of valid, distinct data points from different individuals.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # ResponseId as the unique identifier: The ResponseId column serves as the primary unique identifier for each survey entry. Any rows with identical ResponseIds (and all other columns) are considered true, complete duplicates and must be removed to ensure data integrity and accurate representation of the number of survey participants.
# MainBranch, Employment, RemoteWork for pattern analysis: These columns were selected for identifying 'shared response patterns' because they represent fundamental demographic and professional characteristics of the respondents. Analyzing duplicates based on these columns helped us understand how many different individuals exhibit similar profiles, which is valuable for segmenting the data but does not warrant their removal as duplicates.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
